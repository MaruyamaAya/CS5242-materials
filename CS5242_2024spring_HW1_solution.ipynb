# %% [markdown]
# \# Welcome to CS 5242 **Homework 1**
#
# ASSIGNMENT DEADLINE ⏰ : **23:59 04 Feb 2024**
#
# In this assignment, the task is to implement Multi-Layer Perceptron (MLP) for predicting the price of houses in Boston from scratch.
#
# Colab is a hosted Jupyter notebook service that requires no setup to use, while providing access free of charge to computing resources including GPUs. In this semester, we will use Colab to run our experiments.
#
# > In this assignment, there is no need to use GPU.
#
# ### **Grades Policy**
#
# We have 10 points for this homework. 15% off per day late, 0 scores if you submit it 7 days after the deadline.
#
# ### **Cautions**
#
# **DO NOT** use external libraries like PyTorch or TensorFlow in your implementation.
#
# **DO NOT** copy the code from the internet, e.g. GitHub.
#
# ---
#
# ### **Contact**
#
# Please feel free to contact us if you have any question about this homework or need any further information.
#
# Slack: Ziming Liu
#
# TA Email: liuziming@comp.nus.edu.sg

# %% [markdown]
# ## Setup
#
# Start by running the cell below to set up all required software.

# %%
# !pip install numpy matplotlib scikit-learn
# Out:
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (1.23.5)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (3.7.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (1.2.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (4.47.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.11.4)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (3.2.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %% [markdown]
# Import the neccesary library.

# %%
import time

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.datasets import fetch_california_housing

# %% [markdown]
# Everything is ready, you can move on and ***Good Luck !*** 😃

# %% [markdown]
# ## Explore Boston Housing Dataset
#
# One of the first steps when working with a new data set is exploring.The Boston Housing Dataset is a derived from information collected by the U.S. Census Service concerning housing in the area of Boston MA. The following describes the dataset columns:
#
# CRIM - per capita crime rate by town
#
# ZN - proportion of residential land zoned for lots over 25,000 sq.ft.
#
# INDUS - proportion of non-retail business acres per town.
#
# CHAS - Charles River dummy variable (1 if tract bounds river; 0 otherwise)
#
# NOX - nitric oxides concentration (parts per 10 million)
#
# RM - average number of rooms per dwelling
#
# AGE - proportion of owner-occupied units built prior to 1940
#
# DIS - weighted distances to five Boston employment centres
#
# RAD - index of accessibility to radial highways
#
# TAX - full-value property-tax rate per $10,000
#
# PTRATIO - pupil-teacher ratio by town
#
# B - 1000(Bk - 0.63)^2 where Bk is the proportion of blacks by town
#
# LSTAT - % lower status of the population
#
# MEDV - Median value of owner-occupied homes in $1000's
#
# First, we download the dataset from the Internet.

# %%
# !mkdir -p data \
    && cd data \
    && wget -q https://archive.ics.uci.edu/ml/machine-learning-databases/housing/housing.data \
    && ls -l .
# Out:
# total 48
# -rw-r--r-- 1 root root 49082 Jan 18 10:48 housing.data

# %% [markdown]
# The next thing to do is to reformat the data. Now we reshape the data into a (num_sample, num_features) array.

# %%
datafile = 'data/housing.data'
data = np.fromfile(datafile, sep=' ')
feature_names = ['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT', 'MEDV']
print(data.shape)
feature_num = len(feature_names)
data = data.reshape([data.shape[0] // feature_num, feature_num])
print(data.shape)
# Out:
# (7084,)
# (506, 14)

# %% [markdown]
# One important step of data processing is to rescale the features. In this case, we use minmax scaling. After rescaling, the range of the data will become 0-1.

# %%
# rescale data using minmax scaling.
def scale_data(X):
    X_scaled = None
    #########Enter your code here######### (One point)
    X_scaled = np.apply_along_axis(lambda x: (x - np.min(x)) / (np.max(x) - np.min(x)), 0, X)
    #########Code end#########
    return X_scaled

# %%
ratio = 0.8
offset = int(data.shape[0] * ratio)

# %%
x = data[:, :-1]
y = data[:, -1:]
x = scale_data(x)
X_train = x[:offset]
X_test = x[offset:]
Y_train = y[:offset]
Y_test = y[offset:]

# %% [markdown]
# An easy to quickly get an idea for how your data looks is to examine the shape of the matrix it's stored using the `.shape` attribute of numpy arrays. We see that the shape of `X_train` is `404 x 13`, which tells us there are `404` samples (images) each with dimension `13`.

# %%
print(f"The shape of the training set is: {X_train.shape[0]} x {X_train.shape[1]}")
print(f"The shape of the test set is: {X_test.shape[0]} x {X_test.shape[1]}")
# Out:
# The shape of the training set is: 404 x 13
# The shape of the test set is: 102 x 13

# %% [markdown]
# Now lets take a look at how the samples are represented, we can do this by calling `Y_train[index]` and `X_train[index]` (here I choose `index=0` to look at the very first sample). We first notice `Y_train[0]=24`, meaning this entry is a house worthy of 24. The data type of the numpy array is float64 by default.

# %%
index = 0
print(f"Y_train[{index}]: {Y_train[index]}")
print(X_train[index])
print(X_train[index].dtype)
# Out:
# Y_train[0]: [24.]
# [0.         0.18       0.06781525 0.         0.31481481 0.57750527
#  0.64160659 0.26920314 0.         0.20801527 0.28723404 1.
#  0.08967991]
# float64

# %% [markdown]
# We can also check how related the features are with the house price.

# %%
housedatadf=pd.DataFrame(data=X_train,columns=feature_names[:-1])
housedatadf["target"]=Y_train
datacor=np.corrcoef(housedatadf.values,rowvar=0)
datacor=pd.DataFrame(data=datacor,columns=housedatadf.columns,index=housedatadf.columns)
plt.figure(figsize=(15,10))
ax=sns.heatmap(datacor,square=True,annot=True,fmt=".3f",linewidths=5,cmap="YlGnBu",cbar_kws={"fraction":0.046,"pad":0.03})
plt.show()

# %% [markdown]
# ## Implementation of Multilayer perceptron

# %% [markdown]
# We'll first go through and write the code for each piece of an MLP in generic Python functions. We'll then wrap everything in an `MLP` class, which will allow us to easily access all the MLP functionality in a user friendly manner.

# %% [markdown]
# ### Training

# %% [markdown]
# You have **three tasks** in this section.
# 1. You need to implement `__init__` function
# 1. You need to implement `mse_loss` function
# 2. You need to implement `forward` function.
# 3. You need to implement `backward` function.
# 4. You need to implement the main loop of `train` function.

# %%
class MLP(object):
    def __init__(self, num_of_weights, learning_rate=0.01):
        np.random.seed(42)
        self.learning_rate = learning_rate
        # As this is a very simple problem, we only need one linear layer here.
        # Init a linear layer with weight(using standard normal distribution) and bias(to 0).
        #########Enter your code here#########  (One point)
        self.weight = np.random.randn(num_of_weights, 1)
        self.bias = 0
        #########Code end#########

    def mse_loss(self, y_pred, y):

        #########Enter your code here#########  (One point)
        error = y_pred - y
        loss_ = np.mean(error * error)
        #########Code end#########
        return loss_

    def forward(self, x):

        #########Enter your code here#########  (Two points)
        out_ = np.dot(x, self.weight) + self.bias
        #########Code end#########
        return out_

    def backward(self, x, y_pred, y):

        # Calculate the gradient and update the weight and bias using the gradient.
        #########Enter your code here######### (Two points)
        gradient_w = (y_pred - y) * x
        gradient_w = np.mean(gradient_w, axis=0)
        gradient_w = gradient_w[:, np.newaxis]
        gradient_b = (y_pred - y)
        gradient_b = np.mean(gradient_b)
        self.weight = self.weight - self.learning_rate * gradient_w
        self.bias = self.bias - self.learning_rate * gradient_b
        #########Code end#########


    def train(self, X, Y, num_epoches, batch_size):
        n_samples = len(X)
        losses = []
        for epoch_id in range(num_epoches):
            shuffle = np.random.permutation(n_samples)
            X_batches = np.array_split(X[shuffle], n_samples / batch_size)
            Y_batches = np.array_split(Y[shuffle], n_samples / batch_size)
            iter_id = 0
            for batch_x, batch_y in zip(X_batches, Y_batches):
                #########Enter your code here######### (One point)
                out_ = self.forward(batch_x)
                loss = self.mse_loss(out_, batch_y)
                self.backward(batch_x, out_, batch_y)
                losses.append(loss)
                #########Code end#########
                print('Epoch {:3d} / iter {:3d}, loss={:4f}'.format(epoch_id + 1, iter_id, loss))
                iter_id += 1
        return losses

# %% [markdown]
# Great, now let's give this a try. Let's create a really simple MLP. We'll train with a `batch_size=100` for `epochs=50` and a learning rate `lr=0.1`.

# %%
network = MLP(13, 0.1)
losses = network.train(X_train, Y_train, num_epoches=50, batch_size=100)
plot_x = np.arange(len(losses))
plot_y = np.array(losses)
plt.plot(plot_x, plot_y)
plt.show()
# Out:
# Epoch   1 / iter   0, loss=616.363963
# Epoch   1 / iter   1, loss=311.675004
# Epoch   1 / iter   2, loss=227.758170
# Epoch   1 / iter   3, loss=165.000258
# Epoch   2 / iter   0, loss=88.606598
# Epoch   2 / iter   1, loss=124.101793
# Epoch   2 / iter   2, loss=111.136857
# Epoch   2 / iter   3, loss=121.332435
# Epoch   3 / iter   0, loss=112.478357
# Epoch   3 / iter   1, loss=102.100767
# Epoch   3 / iter   2, loss=88.178325
# Epoch   3 / iter   3, loss=86.786194
# Epoch   4 / iter   0, loss=80.939870
# Epoch   4 / iter   1, loss=115.179444
# Epoch   4 / iter   2, loss=70.218701
# Epoch   4 / iter   3, loss=96.180788
# Epoch   5 / iter   0, loss=98.063773
# Epoch   5 / iter   1, loss=79.133703
# Epoch   5 / iter   2, loss=58.827251
# Epoch   5 / iter   3, loss=100.392559
# Epoch   6 / iter   0, loss=85.346625
# Epoch   6 / iter   1, loss=73.418168
# Epoch   6 / iter   2, loss=105.388947
# Epoch   6 / iter   3, loss=53.663011
# Epoch   7 / iter   0, loss=60.175211
# Epoch   7 / iter   1, loss=86.270600
# Epoch   7 / iter   2, loss=68.020618
# Epoch   7 / iter   3, loss=85.053388
# Epoch   8 / iter   0, loss=54.662658
# Epoch   8 / iter   1, loss=50.711639
# Epoch   8 / iter   2, loss=83.900252
# Epoch   8 / iter   3, loss=96.108433
# Epoch   9 / iter   0, loss=62.458477
# Epoch   9 / iter   1, loss=79.676331
# Epoch   9 / iter   2, loss=57.475970
# Epoch   9 / iter   3, loss=73.058215
# Epoch  10 / iter   0, loss=75.533575
# Epoch  10 / iter   1, loss=44.909812
# Epoch  10 / iter   2, loss=49.850341
# Epoch  10 / iter   3, loss=91.636921
# Epoch  11 / iter   0, loss=68.568084
# Epoch  11 / iter   1, loss=57.074655
# Epoch  11 / iter   2, loss=74.523893
# Epoch  11 / iter   3, loss=51.954125
# Epoch  12 / iter   0, loss=85.107185
# Epoch  12 / iter   1, loss=49.584652
# Epoch  12 / iter   2, loss=44.658464
# Epoch  12 / iter   3, loss=64.961300
# Epoch  13 / iter   0, loss=57.645648
# Epoch  13 / iter   1, loss=65.973996
# Epoch  13 / iter   2, loss=53.196196
# Epoch  13 / iter   3, loss=59.897819
# Epoch  14 / iter   0, loss=64.606832
# Epoch  14 / iter   1, loss=63.785644
# Epoch  14 / iter   2, loss=52.047322
# Epoch  14 / iter   3, loss=49.393941
# Epoch  15 / iter   0, loss=45.210797
# Epoch  15 / iter   1, loss=57.425130
# Epoch  15 / iter   2, loss=69.318992
# Epoch  15 / iter   3, loss=52.080286
# Epoch  16 / iter   0, loss=55.069986
# Epoch  16 / iter   1, loss=65.018682
# Epoch  16 / iter   2, loss=43.851695
# Epoch  16 / iter   3, loss=54.864586
# Epoch  17 / iter   0, loss=49.286707
# Epoch  17 / iter   1, loss=61.837367
# Epoch  17 / iter   2, loss=46.907382
# Epoch  17 / iter   3, loss=56.205617
# Epoch  18 / iter   0, loss=39.674468
# Epoch  18 / iter   1, loss=61.485631
# Epoch  18 / iter   2, loss=67.896749
# Epoch  18 / iter   3, loss=41.796629
# Epoch  19 / iter   0, loss=45.130502
# Epoch  19 / iter   1, loss=44.375047
# Epoch  19 / iter   2, loss=40.521852
# Epoch  19 / iter   3, loss=76.047760
# Epoch  20 / iter   0, loss=61.824460
# Epoch  20 / iter   1, loss=51.409767
# Epoch  20 / iter   2, loss=42.896364
# Epoch  20 / iter   3, loss=45.796997
# Epoch  21 / iter   0, loss=67.171351
# Epoch  21 / iter   1, loss=33.465803
# Epoch  21 / iter   2, loss=48.483162
# Epoch  21 / iter   3, loss=49.146055
# Epoch  22 / iter   0, loss=40.043027
# Epoch  22 / iter   1, loss=38.097163
# Epoch  22 / iter   2, loss=29.333632
# Epoch  22 / iter   3, loss=89.488846
# Epoch  23 / iter   0, loss=46.345328
# Epoch  23 / iter   1, loss=47.778663
# Epoch  23 / iter   2, loss=46.494918
# Epoch  23 / iter   3, loss=51.353550
# Epoch  24 / iter   0, loss=43.293124
# Epoch  24 / iter   1, loss=40.834266
# Epoch  24 / iter   2, loss=57.723917
# Epoch  24 / iter   3, loss=47.066224
# Epoch  25 / iter   0, loss=44.378316
# Epoch  25 / iter   1, loss=43.589556
# Epoch  25 / iter   2, loss=40.982149
# Epoch  25 / iter   3, loss=56.655000
# Epoch  26 / iter   0, loss=40.674419
# Epoch  26 / iter   1, loss=62.462791
# Epoch  26 / iter   2, loss=43.104006
# Epoch  26 / iter   3, loss=37.444335
# Epoch  27 / iter   0, loss=53.717288
# Epoch  27 / iter   1, loss=49.046404
# Epoch  27 / iter   2, loss=29.233178
# Epoch  27 / iter   3, loss=49.019081
# Epoch  28 / iter   0, loss=45.310073
# Epoch  28 / iter   1, loss=36.999602
# Epoch  28 / iter   2, loss=50.701500
# Epoch  28 / iter   3, loss=45.725784
# Epoch  29 / iter   0, loss=34.463067
# Epoch  29 / iter   1, loss=51.608625
# Epoch  29 / iter   2, loss=50.244023
# Epoch  29 / iter   3, loss=39.981082
# Epoch  30 / iter   0, loss=49.946402
# Epoch  30 / iter   1, loss=50.822530
# Epoch  30 / iter   2, loss=45.683963
# Epoch  30 / iter   3, loss=28.334082
# Epoch  31 / iter   0, loss=43.613409
# Epoch  31 / iter   1, loss=64.955021
# Epoch  31 / iter   2, loss=41.789262
# Epoch  31 / iter   3, loss=21.742223
# Epoch  32 / iter   0, loss=33.666756
# Epoch  32 / iter   1, loss=56.979079
# Epoch  32 / iter   2, loss=31.666892
# Epoch  32 / iter   3, loss=47.333981
# Epoch  33 / iter   0, loss=60.480930
# Epoch  33 / iter   1, loss=31.813409
# Epoch  33 / iter   2, loss=37.793003
# Epoch  33 / iter   3, loss=38.177298
# Epoch  34 / iter   0, loss=47.226019
# Epoch  34 / iter   1, loss=27.125042
# Epoch  34 / iter   2, loss=51.896956
# Epoch  34 / iter   3, loss=39.688894
# Epoch  35 / iter   0, loss=33.778602
# Epoch  35 / iter   1, loss=36.926128
# Epoch  35 / iter   2, loss=53.458555
# Epoch  35 / iter   3, loss=39.794807
# Epoch  36 / iter   0, loss=55.737448
# Epoch  36 / iter   1, loss=37.903667
# Epoch  36 / iter   2, loss=25.638687
# Epoch  36 / iter   3, loss=42.831695
# Epoch  37 / iter   0, loss=31.567666
# Epoch  37 / iter   1, loss=51.561947
# Epoch  37 / iter   2, loss=35.203491
# Epoch  37 / iter   3, loss=42.017926
# Epoch  38 / iter   0, loss=61.284133
# Epoch  38 / iter   1, loss=29.498655
# Epoch  38 / iter   2, loss=32.370974
# Epoch  38 / iter   3, loss=36.275528
# Epoch  39 / iter   0, loss=34.709859
# Epoch  39 / iter   1, loss=30.490088
# Epoch  39 / iter   2, loss=52.030790
# Epoch  39 / iter   3, loss=39.815488
# Epoch  40 / iter   0, loss=45.699107
# Epoch  40 / iter   1, loss=30.438997
# Epoch  40 / iter   2, loss=40.872286
# Epoch  40 / iter   3, loss=38.755194
# Epoch  41 / iter   0, loss=47.698308
# Epoch  41 / iter   1, loss=34.650288
# Epoch  41 / iter   2, loss=37.240605
# Epoch  41 / iter   3, loss=34.522193
# Epoch  42 / iter   0, loss=51.610103
# Epoch  42 / iter   1, loss=22.432498
# Epoch  42 / iter   2, loss=60.308502
# Epoch  42 / iter   3, loss=19.694148
# Epoch  43 / iter   0, loss=27.651704
# Epoch  43 / iter   1, loss=37.178559
# Epoch  43 / iter   2, loss=51.612412
# Epoch  43 / iter   3, loss=34.750769
# Epoch  44 / iter   0, loss=38.249849
# Epoch  44 / iter   1, loss=38.213124
# Epoch  44 / iter   2, loss=47.486139
# Epoch  44 / iter   3, loss=25.966129
# Epoch  45 / iter   0, loss=47.956402
# Epoch  45 / iter   1, loss=23.828672
# Epoch  45 / iter   2, loss=49.294087
# Epoch  45 / iter   3, loss=27.824391
# Epoch  46 / iter   0, loss=34.924391
# Epoch  46 / iter   1, loss=36.192943
# Epoch  46 / iter   2, loss=31.064647
# Epoch  46 / iter   3, loss=45.301869
# Epoch  47 / iter   0, loss=39.632886
# Epoch  47 / iter   1, loss=45.838120
# Epoch  47 / iter   2, loss=28.111698
# Epoch  47 / iter   3, loss=32.597346
# Epoch  48 / iter   0, loss=38.049060
# Epoch  48 / iter   1, loss=28.108350
# Epoch  48 / iter   2, loss=43.190736
# Epoch  48 / iter   3, loss=36.045739
# Epoch  49 / iter   0, loss=41.483977
# Epoch  49 / iter   1, loss=27.995769
# Epoch  49 / iter   2, loss=38.752754
# Epoch  49 / iter   3, loss=35.477998
# Epoch  50 / iter   0, loss=43.281654
# Epoch  50 / iter   1, loss=44.586758
# Epoch  50 / iter   2, loss=28.081119
# Epoch  50 / iter   3, loss=27.256188

# %% [markdown]
# Now we can check the performance on the test set!

# %%
Y_pred=network.forward(X_test)
# mse=mean_absolute_error(y_test,pre_y)
Y_pred = np.squeeze(Y_pred)
Y_test = np.squeeze(Y_test)
index=np.argsort(Y_test)
plt.figure(figsize=(12,5))
plt.plot(np.arange(len(Y_test)),Y_test[index],"r",label="original y")
plt.scatter(np.arange(len(Y_test)),Y_pred[index],s=3,c="b",label="prediction")
plt.legend(loc="upper left")
plt.grid()
plt.xlabel("index")
plt.ylabel("y")
plt.show()

# %% [markdown]
# ## Discussion (2 points)
#
# In this section, you are free to choose some of the following directions to explore, and try to summarize some patterns and conclusions.
#
# * Try to use different learning rates and generalize the impact of learning rate on training.
# * Try to use different ways of weight initialization and explore the impact on the convergence and final classification performance.
# * Try to use a portion of the data for training (e.g., 10%, 20%, 50%) to explore the training convergence and final classification performance with different amounts of data.
#
# > **NOTE:** *Good Disscusion* include experimental setup, presentation of experimental results including visualization, analysis and interpretation of phenomena, and summary of conclusions

# %%
# === Complete the code (2')

# === Complete the code

# %% [markdown]
# Write down your analysis and conclusions:
